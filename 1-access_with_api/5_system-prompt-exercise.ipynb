# %%
from dotenv import load_dotenv

load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None):
    params = {
        "model":model,
        "max_tokens":1000,
        "messages":messages
    }
    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

system_prompt = """
    You are a python engineer who writes very clear and concise code.
    """

add_user_message(
    messages, 
    "Write a python function that checks a string for duplicate characters."
)
answer = chat(messages, system=system_prompt)

print(f"{answer}")
# Out:
# Here's a clean and concise function that checks a string for duplicate characters:
#
# ```python
# def has_duplicates(s: str) -> bool:
#     """Returns True if the string contains duplicate characters, False otherwise."""
#     return len(s) != len(set(s))
# ```
#
# **How it works:**
# - Converts the string to a `set`, which automatically removes duplicates
# - If the lengths differ, duplicates exist
#
# ---
#
# **Example usage:**
# ```python
# print(has_duplicates("hello"))   # True  ('l' appears twice)
# print(has_duplicates("world"))   # False (all unique)
# print(has_duplicates("python"))  # False (all unique)
# print(has_duplicates("abcabc"))  # True  ('a', 'b', 'c' repeat)
# ```
#
# ---
#
# If you'd also like to **identify which characters are duplicated**, here's an extended version:
#
# ```python
# def find_duplicates(s: str) -> list:
#     """Returns a list of characters that appear more than once in the string."""
#     seen = set()
#     duplicates = set()
#
#     for char in s:
#         if char in seen:
#             duplicates.add(char)
#         seen.add(char)
#
#     return sorted(duplicates)
# ```
#
# **Example usage:**
# ```python
# print(find_duplicates("hello"))   # ['l']
# print(find_duplicates("abcabc"))  # ['a', 'b', 'c']
# print(find_duplicates("world"))   # []
# ```
